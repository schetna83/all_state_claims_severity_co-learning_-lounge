# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
train.shape, test.shape
# Out:
# ((188318, 132), (125546, 131))

# %%
train.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6     cont7  \
# 0   1    A    B    A    B    A    A    A    A    B  ...  0.718367  0.335060
# 1   2    A    B    A    A    A    A    A    A    B  ...  0.438917  0.436585
# 2   5    A    B    A    A    B    A    A    A    B  ...  0.289648  0.315545
# 3  10    B    B    A    B    A    A    A    A    B  ...  0.440945  0.391128
# 4  11    A    B    A    B    A    A    A    A    B  ...  0.178193  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14     loss
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843  2213.18
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496  1283.60
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425  3005.09
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642   939.85
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606  2763.85
#
# [5 rows x 132 columns]

# %%
train.columns.values
# Out:
# array(['id', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7',
#        'cat8', 'cat9', 'cat10', 'cat11', 'cat12', 'cat13', 'cat14',
#        'cat15', 'cat16', 'cat17', 'cat18', 'cat19', 'cat20', 'cat21',
#        'cat22', 'cat23', 'cat24', 'cat25', 'cat26', 'cat27', 'cat28',
#        'cat29', 'cat30', 'cat31', 'cat32', 'cat33', 'cat34', 'cat35',
#        'cat36', 'cat37', 'cat38', 'cat39', 'cat40', 'cat41', 'cat42',
#        'cat43', 'cat44', 'cat45', 'cat46', 'cat47', 'cat48', 'cat49',
#        'cat50', 'cat51', 'cat52', 'cat53', 'cat54', 'cat55', 'cat56',
#        'cat57', 'cat58', 'cat59', 'cat60', 'cat61', 'cat62', 'cat63',
#        'cat64', 'cat65', 'cat66', 'cat67', 'cat68', 'cat69', 'cat70',
#        'cat71', 'cat72', 'cat73', 'cat74', 'cat75', 'cat76', 'cat77',
#        'cat78', 'cat79', 'cat80', 'cat81', 'cat82', 'cat83', 'cat84',
#        'cat85', 'cat86', 'cat87', 'cat88', 'cat89', 'cat90', 'cat91',
#        'cat92', 'cat93', 'cat94', 'cat95', 'cat96', 'cat97', 'cat98',
#        'cat99', 'cat100', 'cat101', 'cat102', 'cat103', 'cat104',
#        'cat105', 'cat106', 'cat107', 'cat108', 'cat109', 'cat110',
#        'cat111', 'cat112', 'cat113', 'cat114', 'cat115', 'cat116',
#        'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13', 'cont14',
#        'loss'], dtype=object)

# %%
for i in range(1,117):
    print("cat{}".format(i))
    print(train["cat{}".format(i)].value_counts())
    print(".............")
# Out:
# cat1
# A    141550
# B     46768
# Name: cat1, dtype: int64
# .............
# cat2
# A    106721
# B     81597
# Name: cat2, dtype: int64
# .............
# cat3
# A    177993
# B     10325
# Name: cat3, dtype: int64
# .............
# cat4
# A    128395
# B     59923
# Name: cat4, dtype: int64
# .............
# cat5
# A    123737
# B     64581
# Name: cat5, dtype: int64
# .............
# cat6
# A    131693
# B     56625
# Name: cat6, dtype: int64
# .............
# cat7
# A    183744
# B      4574
# Name: cat7, dtype: int64
# .............
# cat8
# A    177274
# B     11044
# Name: cat8, dtype: int64
# .............
# cat9
# A    113122
# B     75196
# Name: cat9, dtype: int64
# .............
# cat10
# A    160213
# B     28105
# Name: cat10, dtype: int64
# .............
# cat11
# A    168186
# B     20132
# Name: cat11, dtype: int64
# .............
# cat12
# A    159825
# B     28493
# Name: cat12, dtype: int64
# .............
# cat13
# A    168851
# B     19467
# Name: cat13, dtype: int64
# .............
# cat14
# A    186041
# B      2277
# Name: cat14, dtype: int64
# .............
# cat15
# A    188284
# B        34
# Name: cat15, dtype: int64
# .............
# cat16
# A    181843
# B      6475
# Name: cat16, dtype: int64
# .............
# cat17
# A    187009
# B      1309
# Name: cat17, dtype: int64
# .............
# cat18
# A    187331
# B       987
# Name: cat18, dtype: int64
# .............
# cat19
# A    186510
# B      1808
# Name: cat19, dtype: int64
# .............
# cat20
# A    188114
# B       204
# Name: cat20, dtype: int64
# .............
# cat21
# A    187905
# B       413
# Name: cat21, dtype: int64
# .............
# cat22
# A    188275
# B        43
# Name: cat22, dtype: int64
# .............
# cat23
# A    157445
# B     30873
# Name: cat23, dtype: int64
# .............
# cat24
# A    181977
# B      6341
# Name: cat24, dtype: int64
# .............
# cat25
# A    169969
# B     18349
# Name: cat25, dtype: int64
# .............
# cat26
# A    177119
# B     11199
# Name: cat26, dtype: int64
# .............
# cat27
# A    168250
# B     20068
# Name: cat27, dtype: int64
# .............
# cat28
# A    180938
# B      7380
# Name: cat28, dtype: int64
# .............
# cat29
# A    184593
# B      3725
# Name: cat29, dtype: int64
# .............
# cat30
# A    184760
# B      3558
# Name: cat30, dtype: int64
# .............
# cat31
# A    182980
# B      5338
# Name: cat31, dtype: int64
# .............
# cat32
# A    187107
# B      1211
# Name: cat32, dtype: int64
# .............
# cat33
# A    187361
# B       957
# Name: cat33, dtype: int64
# .............
# cat34
# A    187734
# B       584
# Name: cat34, dtype: int64
# .............
# cat35
# A    188105
# B       213
# Name: cat35, dtype: int64
# .............
# cat36
# A    156313
# B     32005
# Name: cat36, dtype: int64
# .............
# cat37
# A    165729
# B     22589
# Name: cat37, dtype: int64
# .............
# cat38
# A    169323
# B     18995
# Name: cat38, dtype: int64
# .............
# cat39
# A    183393
# B      4925
# Name: cat39, dtype: int64
# .............
# cat40
# A    180119
# B      8199
# Name: cat40, dtype: int64
# .............
# cat41
# A    181177
# B      7141
# Name: cat41, dtype: int64
# .............
# cat42
# A    186623
# B      1695
# Name: cat42, dtype: int64
# .............
# cat43
# A    184110
# B      4208
# Name: cat43, dtype: int64
# .............
# cat44
# A    172716
# B     15602
# Name: cat44, dtype: int64
# .............
# cat45
# A    183991
# B      4327
# Name: cat45, dtype: int64
# .............
# cat46
# A    187436
# B       882
# Name: cat46, dtype: int64
# .............
# cat47
# A    187617
# B       701
# Name: cat47, dtype: int64
# .............
# cat48
# A    188049
# B       269
# Name: cat48, dtype: int64
# .............
# cat49
# A    179127
# B      9191
# Name: cat49, dtype: int64
# .............
# cat50
# A    137611
# B     50707
# Name: cat50, dtype: int64
# .............
# cat51
# A    187071
# B      1247
# Name: cat51, dtype: int64
# .............
# cat52
# A    179505
# B      8813
# Name: cat52, dtype: int64
# .............
# cat53
# A    172949
# B     15369
# Name: cat53, dtype: int64
# .............
# cat54
# A    183762
# B      4556
# Name: cat54, dtype: int64
# .............
# cat55
# A    188173
# B       145
# Name: cat55, dtype: int64
# .............
# cat56
# A    188136
# B       182
# Name: cat56, dtype: int64
# .............
# cat57
# A    185296
# B      3022
# Name: cat57, dtype: int64
# .............
# cat58
# A    188079
# B       239
# Name: cat58, dtype: int64
# .............
# cat59
# A    188018
# B       300
# Name: cat59, dtype: int64
# .............
# cat60
# A    187872
# B       446
# Name: cat60, dtype: int64
# .............
# cat61
# A    187596
# B       722
# Name: cat61, dtype: int64
# .............
# cat62
# A    188273
# B        45
# Name: cat62, dtype: int64
# .............
# cat63
# A    188239
# B        79
# Name: cat63, dtype: int64
# .............
# cat64
# A    188271
# B        47
# Name: cat64, dtype: int64
# .............
# cat65
# A    186056
# B      2262
# Name: cat65, dtype: int64
# .............
# cat66
# A    179982
# B      8336
# Name: cat66, dtype: int64
# .............
# cat67
# A    187626
# B       692
# Name: cat67, dtype: int64
# .............
# cat68
# A    188176
# B       142
# Name: cat68, dtype: int64
# .............
# cat69
# A    188011
# B       307
# Name: cat69, dtype: int64
# .............
# cat70
# A    188295
# B        23
# Name: cat70, dtype: int64
# .............
# cat71
# A    178646
# B      9672
# Name: cat71, dtype: int64
# .............
# cat72
# A    118322
# B     69996
# Name: cat72, dtype: int64
# .............
# cat73
# A    154275
# B     34017
# C        26
# Name: cat73, dtype: int64
# .............
# cat74
# A    184731
# B      3561
# C        26
# Name: cat74, dtype: int64
# .............
# cat75
# A    154307
# B     34010
# C         1
# Name: cat75, dtype: int64
# .............
# cat76
# A    181347
# B      6183
# C       788
# Name: cat76, dtype: int64
# .............
# cat77
# D    187503
# C       408
# B       358
# A        49
# Name: cat77, dtype: int64
# .............
# cat78
# B    186526
# A       788
# C       645
# D       359
# Name: cat78, dtype: int64
# .............
# cat79
# B    152929
# D     26657
# A      7064
# C      1668
# Name: cat79, dtype: int64
# .............
# cat80
# D    137505
# B     46538
# C      3492
# A       783
# Name: cat80, dtype: int64
# .............
# cat81
# D    154385
# B     24132
# C      9013
# A       788
# Name: cat81, dtype: int64
# .............
# cat82
# B    147536
# A     19322
# D     18805
# C      2655
# Name: cat82, dtype: int64
# .............
# cat83
# B    141534
# A     26038
# D     15788
# C      4958
# Name: cat83, dtype: int64
# .............
# cat84
# C    154939
# A     29450
# D      3498
# B       431
# Name: cat84, dtype: int64
# .............
# cat85
# B    186005
# C      1011
# A       788
# D       514
# Name: cat85, dtype: int64
# .............
# cat86
# B    103852
# D     72587
# C     10290
# A      1589
# Name: cat86, dtype: int64
# .............
# cat87
# B    166992
# D     11719
# C      8819
# A       788
# Name: cat87, dtype: int64
# .............
# cat88
# A    168926
# D     19302
# E        83
# B         7
# Name: cat88, dtype: int64
# .............
# cat89
# A    183744
# B      4312
# C       220
# D        33
# E         5
# I         2
# G         1
# H         1
# Name: cat89, dtype: int64
# .............
# cat90
# A    177993
# B      9515
# C       728
# D        70
# E         6
# F         4
# G         2
# Name: cat90, dtype: int64
# .............
# cat91
# A    111028
# B     42630
# G     26734
# C      6400
# D      1149
# E       254
# F        97
# H        26
# Name: cat91, dtype: int64
# .............
# cat92
# A    124689
# H     62901
# B       628
# C        62
# I        26
# D        11
# F         1
# Name: cat92, dtype: int64
# .............
# cat93
# D    150237
# C     35788
# B      1133
# E       728
# A       432
# Name: cat93, dtype: int64
# .............
# cat94
# D    121642
# B     51710
# C     13623
# A       738
# F       494
# E        91
# G        20
# Name: cat94, dtype: int64
# .............
# cat95
# C    87531
# D    79525
# E    17417
# A     3736
# B      109
# Name: cat95, dtype: int64
# .............
# cat96
# E    174360
# D      7922
# B      2957
# G      2665
# F       343
# A        35
# C        24
# I        12
# Name: cat96, dtype: int64
# .............
# cat97
# C    78127
# E    47450
# A    41970
# G    16745
# D     3779
# F      213
# B       34
# Name: cat97, dtype: int64
# .............
# cat98
# A    105492
# D     50557
# C     21485
# E     10242
# B       542
# Name: cat98, dtype: int64
# .............
# cat99
# P    79455
# T    72591
# R    10290
# D     8844
# S     7045
# N     2894
# K     2703
# F     2702
# E     1034
# C      310
# J      245
# H       93
# M       52
# I       38
# G       19
# O        3
# Name: cat99, dtype: int64
# .............
# cat100
# F    42970
# I    39933
# L    19961
# K    13817
# G    12935
# J    12027
# H    10776
# A     9402
# N     7592
# B     6608
# O     5697
# M     5185
# C      836
# D      553
# E       26
# Name: cat100, dtype: int64
# .............
# cat101
# A    106721
# D     17171
# C     16971
# G     10944
# F     10139
# J      7259
# I      6690
# M      3669
# L      3173
# Q      2762
# O      2493
# S       173
# R       138
# E         7
# B         3
# K         2
# U         1
# H         1
# N         1
# Name: cat101, dtype: int64
# .............
# cat102
# A    177274
# B      5155
# C      4929
# E       482
# D       449
# G        15
# F        12
# H         1
# J         1
# Name: cat102, dtype: int64
# .............
# cat103
# A    123737
# B     33342
# C     16508
# D      7806
# E      4473
# F      1528
# G       550
# H       190
# I       109
# J        45
# L        17
# K        11
# N         2
# Name: cat103, dtype: int64
# .............
# cat104
# E    42925
# G    40660
# D    27611
# F    19228
# H    17187
# K    14297
# I    10919
# C     6949
# L     3486
# J     3138
# M     1156
# O      409
# N      153
# P       86
# A       68
# B       43
# Q        3
# Name: cat104, dtype: int64
# .............
# cat105
# E    76493
# F    62892
# G    20613
# D    12172
# H    11258
# I     2941
# J      694
# K      486
# C      275
# M      171
# L      145
# A       77
# N       64
# P       15
# O        9
# B        5
# Q        4
# R        2
# T        1
# S        1
# Name: cat105, dtype: int64
# .............
# cat106
# G    47165
# H    37713
# F    36143
# I    21433
# J    18281
# E    13000
# K     7958
# L     2971
# D     1934
# M     1176
# N      231
# C      129
# A       75
# O       66
# R       32
# B        9
# P        2
# Name: cat106, dtype: int64
# .............
# cat107
# F    47310
# G    28560
# H    23461
# J    22405
# K    20236
# I    20066
# E    12521
# L     6976
# D     3225
# M     2067
# N      797
# C      213
# Q      140
# O      125
# P      100
# A       75
# U       32
# R        5
# B        2
# S        2
# Name: cat107, dtype: int64
# .............
# cat108
# B    65512
# K    42435
# G    21421
# D    19160
# F    10242
# A     9299
# E     7968
# I     7243
# H     4305
# C      520
# J      213
# Name: cat108, dtype: int64
# .............
# cat109
# BI    152918
# AB     21933
# BU      3142
# K       2999
# G       1353
# BQ      1067
# N        461
# M        446
# BO       329
# BH       257
# D        214
# AR       208
# AT       200
# CL       178
# AS       159
# AL       151
# R        149
# CD       143
# F        124
# BL       122
# CI       109
# I         94
# L         89
# U         78
# AW        74
# H         73
# Q         66
# CA        66
# BX        61
# T         59
#        ...
# AA        14
# CK        13
# CF        12
# V         11
# BS         9
# AY         9
# CE         8
# CG         8
# CJ         8
# P          8
# AF         8
# AP         7
# CH         6
# AV         6
# BE         5
# BG         3
# BY         3
# BT         2
# BN         2
# BM         2
# BV         2
# AO         2
# J          1
# AK         1
# B          1
# AG         1
# ZZ         1
# BF         1
# CB         1
# BP         1
# Name: cat109, Length: 84, dtype: int64
# .............
# cat110
# CL    25305
# EG    24654
# CS    24592
# EB    21396
# CO    17495
# BT    16365
# EL     9236
# BC     4131
# DW     3640
# CQ     3271
# DX     3096
# AI     2965
# BP     2867
# W      2703
# C      2681
# AC     2611
# CM     1925
# BS     1920
# DK     1745
# V      1692
# A      1296
# EE     1185
# EF     1159
# CI     1066
# DM      796
# CR      767
# AM      643
# AD      626
# AP      576
# T       529
#       ...
# CW        8
# BY        8
# CD        8
# AG        7
# BB        6
# CX        6
# BU        4
# DB        4
# AH        4
# EK        4
# AF        3
# DD        3
# AN        3
# Q         3
# DT        3
# EJ        2
# BN        2
# DN        2
# CU        2
# EI        2
# BV        2
# DV        1
# S         1
# BD        1
# EH        1
# BM        1
# BI        1
# BK        1
# CB        1
# AS        1
# Name: cat110, Length: 131, dtype: int64
# .............
# cat111
# A    128395
# C     32401
# E     14682
# G      7039
# I      3578
# K      1353
# M       473
# O       221
# Q        91
# S        38
# W        16
# U        16
# B         7
# F         3
# D         3
# Y         2
# Name: cat111, dtype: int64
# .............
# cat112
# E     25148
# AH    18639
# AS    17669
# J     16222
# AF     9368
# AN     9138
# N      8453
# U      8356
# AV     7122
# AK     6726
# K      6059
# AI     4749
# S      4201
# AP     4000
# G      3168
# F      3149
# AW     3145
# A      2411
# AR     2365
# C      2257
# O      2183
# D      1645
# AD     1531
# AY     1414
# Y      1351
# AG     1331
# AT     1272
# AA     1241
# AM     1170
# AL     1130
# R      1123
# AX     1074
# I       940
# X       925
# AE      834
# Q       793
# V       693
# H       548
# AO      534
# T       521
# L       493
# W       461
# AC      454
# M       439
# AU      434
# B       423
# P       406
# AB      246
# BA      190
# AJ      144
# AQ       30
# Name: cat112, dtype: int64
# .............
# cat113
# BM    26191
# AE    22030
# L     13058
# AX    12661
# Y     11374
# K      7738
# S      7033
# X      7016
# AF     6079
# AN     5214
# H      5094
# AT     4664
# AJ     4425
# AD     4419
# AS     3901
# AK     3520
# BN     3486
# I      3279
# A      3269
# J      3105
# N      2839
# BC     2793
# Q      2784
# BJ     2605
# M      2485
# AG     2415
# AW     1825
# BG     1804
# AU     1630
# AO     1628
#       ...
# BO     1413
# BH     1221
# BK      693
# AV      528
# AY      466
# AM      450
# AI      440
# BF      347
# BD      337
# AH      209
# C       143
# BB       53
# BA       42
# BI       32
# G        18
# AB       18
# AQ       17
# V        15
# U        11
# O        10
# E         7
# AP        6
# BL        3
# BE        3
# AL        3
# T         2
# AR        1
# B         1
# AC        1
# P         1
# Name: cat113, Length: 61, dtype: int64
# .............
# cat114
# A    131693
# C     16793
# E     16475
# J      8199
# F      7905
# N      2455
# I      2432
# R       912
# L       870
# U       250
# O       240
# Q        43
# V        33
# B         6
# D         5
# S         4
# G         1
# W         1
# X         1
# Name: cat114, dtype: int64
# .............
# cat115
# K    43866
# O    26813
# J    23895
# N    22438
# P    21538
# L    16125
# M    12444
# Q     8258
# I     7090
# H     2793
# R     2038
# G      315
# F      269
# S      250
# A       75
# T       56
# U       26
# E       11
# W        6
# X        5
# D        4
# B        2
# C        1
# Name: cat115, dtype: int64
# .............
# cat116
# HK    21061
# DJ    20244
# CK    10162
# DP     9202
# GS     8736
# CR     6862
# HX     5629
# DC     4557
# HG     4414
# IE     4225
# HQ     4044
# HV     3853
# GC     3803
# LM     3277
# LB     3194
# LN     3127
# KW     3085
# HJ     2741
# GK     2632
# DF     2519
# IG     2269
# LO     2082
# HB     2007
# MD     1960
# CB     1909
# LF     1873
# GI     1835
# BY     1620
# KC     1513
# GE     1399
#       ...
# BB        1
# FI        1
# AE        1
# AS        1
# IR        1
# EQ        1
# MH        1
# JI        1
# FN        1
# AR        1
# EV        1
# BF        1
# AD        1
# C         1
# DQ        1
# BI        1
# AH        1
# IK        1
# JT        1
# AT        1
# JO        1
# IO        1
# FS        1
# V         1
# BC        1
# JD        1
# KS        1
# AM        1
# KH        1
# DY        1
# Name: cat116, Length: 326, dtype: int64
# .............

# %%
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6     cont7  \
# 0   1    A    B    A    B    A    A    A    A    B  ...  0.718367  0.335060
# 1   2    A    B    A    A    A    A    A    A    B  ...  0.438917  0.436585
# 2   5    A    B    A    A    B    A    A    A    B  ...  0.289648  0.315545
# 3  10    B    B    A    B    A    A    A    A    B  ...  0.440945  0.391128
# 4  11    A    B    A    B    A    A    A    A    B  ...  0.178193  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14     loss
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843  2213.18
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496  1283.60
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425  3005.09
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642   939.85
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606  2763.85
#
# [5 rows x 132 columns]

# %%
for i in range(1,15):
    sns.lineplot(x=train["cont{}".format(i)], y=train.loss)
    plt.show()

# %%
cor = train[['cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
       'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13', 'cont14']].corr()
sns.heatmap(cor)
# Out:
# /home/chetna/.local/lib/python3.5/site-packages/pandas/core/computation/check.py:19: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.6.1
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
cor
# Out:
#            cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# cont1   1.000000 -0.085180 -0.445431  0.367549 -0.025230  0.758315  0.367384
# cont2  -0.085180  1.000000  0.455861  0.038693  0.191427  0.015864  0.048187
# cont3  -0.445431  0.455861  1.000000 -0.341633  0.089417 -0.349278  0.097516
# cont4   0.367549  0.038693 -0.341633  1.000000  0.163748  0.220932 -0.115064
# cont5  -0.025230  0.191427  0.089417  0.163748  1.000000 -0.149810 -0.249344
# cont6   0.758315  0.015864 -0.349278  0.220932 -0.149810  1.000000  0.658918
# cont7   0.367384  0.048187  0.097516 -0.115064 -0.249344  0.658918  1.000000
# cont8   0.361163  0.137468 -0.185432  0.528740  0.009015  0.437437  0.142042
# cont9   0.929912 -0.032729 -0.417054  0.328961 -0.088202  0.797544  0.384343
# cont10  0.808551  0.063526 -0.325562  0.283294 -0.064967  0.883351  0.492621
# cont11  0.596090  0.116824  0.025271  0.120927 -0.151548  0.773745  0.747108
# cont12  0.614225  0.106250  0.006111  0.130453 -0.148217  0.785144  0.742712
# cont13  0.534850  0.023335 -0.418203  0.179342 -0.082915  0.815091  0.288395
# cont14  0.056688 -0.045584 -0.039592  0.017445 -0.021638  0.042178  0.022286
#
#            cont8     cont9    cont10    cont11    cont12    cont13    cont14
# cont1   0.361163  0.929912  0.808551  0.596090  0.614225  0.534850  0.056688
# cont2   0.137468 -0.032729  0.063526  0.116824  0.106250  0.023335 -0.045584
# cont3  -0.185432 -0.417054 -0.325562  0.025271  0.006111 -0.418203 -0.039592
# cont4   0.528740  0.328961  0.283294  0.120927  0.130453  0.179342  0.017445
# cont5   0.009015 -0.088202 -0.064967 -0.151548 -0.148217 -0.082915 -0.021638
# cont6   0.437437  0.797544  0.883351  0.773745  0.785144  0.815091  0.042178
# cont7   0.142042  0.384343  0.492621  0.747108  0.742712  0.288395  0.022286
# cont8   1.000000  0.452658  0.336588  0.302381  0.315904  0.476402  0.043539
# cont9   0.452658  1.000000  0.785697  0.608000  0.626656  0.642028  0.074154
# cont10  0.336588  0.785697  1.000000  0.702896  0.713812  0.707876  0.041808
# cont11  0.302381  0.608000  0.702896  1.000000  0.994384  0.466247  0.047293
# cont12  0.315904  0.626656  0.713812  0.994384  1.000000  0.478677  0.050267
# cont13  0.476402  0.642028  0.707876  0.466247  0.478677  1.000000  0.047543
# cont14  0.043539  0.074154  0.041808  0.047293  0.050267  0.047543  1.000000

# %% [raw]
# cont12 and cont11 are highly coorelated
# cont1 and cont6
# cont1 and cont9
# cont1 and cont10
# cont1 and cont3
#
# cont2 and

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col3 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col4 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col5 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col6 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col7 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col8 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col9 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col10 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col11 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col12 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow0_col13 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col0 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col2 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col3 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col4 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col5 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col6 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col7 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col8 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col9 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col10 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col11 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col12 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col1 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col4 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col6 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col10 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col11 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow2_col13 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col0 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col2 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col4 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col5 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col7 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col8 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col9 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col10 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col11 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col12 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow3_col13 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow4_col0 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow4_col1 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow4_col2 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_11e0820c_e2d9_11e9_ba6b_94b86deaeb7erow4_col3 {
#             background-color:  #b9d0f9;
#             colo

# %%
train = pd.get_dummies(train)
# Out:
# 0          2213.18
# 1          1283.60
# 2          3005.09
# 3           939.85
# 4          2763.85
# 5          5142.87
# 6          1132.22
# 7          3585.75
# 8         10280.20
# 9          6184.59
# 10         6396.85
# 11         5965.73
# 12         1193.05
# 13         1071.77
# 14          585.18
# 15         1395.45
# 16         6609.32
# 17         2658.70
# 18         4167.32
# 19         3797.89
# 20         1155.48
# 21          891.14
# 22          765.97
# 23          771.58
# 24         7256.49
# 25         1528.73
# 26         4787.07
# 27         2163.97
# 28        11673.03
# 29         1753.50
#             ...
# 188288     2384.79
# 188289      961.10
# 188290     2786.15
# 188291     2157.66
# 188292      644.29
# 188293     4301.82
# 188294     4446.20
# 188295     1996.00
# 188296    16569.90
# 188297     4620.56
# 188298     3201.50
# 188299     1946.11
# 188300      839.41
# 188301      896.57
# 188302     1667.38
# 188303     4003.79
# 188304    12065.38
# 188305     4958.36
# 188306     2594.72
# 188307     1173.30
# 188308     2161.12
# 188309     4080.42
# 188310     4659.57
# 188311      994.85
# 188312      804.28
# 188313     1198.62
# 188314     1108.34
# 188315     5762.64
# 188316     1562.87
# 188317     4751.72
# Name: loss, Length: 188318, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
X = train.drop(columns=['loss'])
y = train.loss
X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.2)
model = DecisionTreeRegressor()
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y_predict = model.predict(X_val)
from sklearn.metrics import mean_squared_error
mean_squared_error(y_predict,y_val)
# Out:
# 7574446.265924914
